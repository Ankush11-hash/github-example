# %%
import pandas as pd
import numpy as np

# %%
Df = pd.read_csv('Final_Df.csv')

# %%
Df.head()
# Out:
#    Unnamed: 0 Postcode      Borough                            Neighborhood
# 0           0      M1B  Scarborough                          Rouge, Malvern
# 1           1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2           2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3           3      M1G  Scarborough                                  Woburn
# 4           4      M1H  Scarborough                               Cedarbrae

# %%
# Download the Geo data from the link available at project decription .
#now read the Geo.csv where cordinated are stored.
df_geo = pd.read_csv('Geo.csv')
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# now we will match the Df['postcode'] with postcode in df_geo['PostalCode'] and assign the lat anad lon
Df['Latitude'] = np.nan
Df['Longitude']= np.nan
for i in range(len(Df)):
    if Df['Postcode'][i]==df_geo['Postal Code'][i]:
        Df['Latitude'].replace(np.nan,df_geo['Latitude'],inplace=True)
        Df['Longitude'].replace(np.nan,df_geo['Longitude'],inplace=True)

# %%
Df
# Out:
#     Unnamed: 0 Postcode      Borough  \
# 0            0      M1B  Scarborough
# 1            1      M1C  Scarborough
# 2            2      M1E  Scarborough
# 3            3      M1G  Scarborough
# 4            4      M1H  Scarborough
# ..         ...      ...          ...
# 82          82      M9L   North York
# 83          83      M9M   North York
# 84          84      M9N         York
# 85          85      M9P    Etobicoke
# 86          86      M9R    Etobicoke
#
#                                          Neighborhood   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 1              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# ..                                                ...        ...        ...
# 82                                      Humber Summit  43.661608 -79.464763
# 83                                   Emery, Humberlea  43.648960 -79.456325
# 84                                             Weston  43.651571 -79.484450
# 85                                          Westmount  43.662301 -79.389494
# 86  Kingsview Village, Martin Grove Gardens, Richv...  43.636966 -79.615819
#
# [87 rows x 6 columns]
